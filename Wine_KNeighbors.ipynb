# %% [markdown]
# # K Neighbors Classifier

# %%
import MyKNeighborsClassifier as KNC
import utils
import importlib
importlib.reload(MyKNeighborsClassifier)
importlib.reload(utils)

#Import mypytable.py
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
from mysklearn.mypytable import MyPyTable 

#Import myevaluation.py
import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation
# Out:
# <module 'utils' from '/home/CPSC322_HaileyChloe/utils.py'>

# %%
importlib.reload(mysklearn.mypytable)
importlib.reload(mysklearn.myevaluation)

nextDoor = KNC.MyKNeighborsClassifier()
table = MyPyTable().load_from_file(os.path.join("input_files","winequality-red.csv"))
y_col = table.get_column("quality", False)
x_cols = table.drop_col("quality")
#wine_table, wine_header = utils.read_table("winequality-red.csv")
#utils.convert_to_numeric(wine_table)
#wine_table_y = utils.get_column(wine_table, wine_header, "quality")

# Remove the class value from the table
for value in wine_table:
    del value[-1]

X_train, X_test, y_train, y_test = utils.train_test_split(wine_table, wine_table_y, .33)

nextDoor.fit(X_train, y_train)
# TODO: Make sure that kneighbors function works the way we want it to
distances, neighbors = nextDoor.kneighbors(X_test)

# TODO: Print to file to see full output
#   Also, format this better
utils.pretty_print(distances)
utils.pretty_print(neighbors)
# Out:
# 6
# 77 77 77 77 77 77 77 77 77 77 77
# 78 78 78 78 78 78 78 78 78 78 78
# 79 79 79 79 79 79 79 79 79 79 79
# 80 80 80 80 80 80 80 80 80 80 80
# 81 81 81 81 81 81 81 81 81 81 81
# 82 82 82 82 82 82 82 82 82 82 82
# 83 83 83 83 83 83 83 83 83 83 83
# 84 84 84 84 84 84 84 84 84 84 84
# 85 85 85 85 85 85 85 85 85 85 85
# 86 86 86 86 86 86 86 86 86 86 86
# 87 87 87 87 87 87 87 87 87 87 87
# 88 88 88 88 88 88 88 88 88 88 88
# 89 89 89 89 89 89 89 89 89 89 89
# 90 90 90 90 90 90 90 90 90 90 90
# 91 91 91 91 91 91 91 91 91 91 91
# 92 92 92 92 92 92 92 92 92 92 92
# 93 93 93 93 93 93 93 93 93 93 93
# 94 94 94 94 94 94 94 94 94 94 94
# 95 95 95 95 95 95 95 95 95 95 95
# 96 96 96 96 96 96 96 96 96 96 96
# 97 97 97 97 97 97 97 97 97 97 97
# 98 98 98 98 98 98 98 98 98 98 98
# 99 99 99 99 99 99 99 99 99 99 99
# 100 100 100 100 100 100 100 100 100 100 100
# 101 101 101 101 101 101 101 101 101 101 101
# 102 102 102 102 102 102 102 102 102 102 102
# 103 103 103 103 103 103 103 103 103 103 103
# ...
